# %% [markdown]
# # Background Modeling
#
# When fitting a spectrum with a background, it is invalid to simply subtract off the background if the background is part of the data's generative model [van Dyk et al. (2001)](http://iopscience.iop.org/article/10.1086/318656/meta). Therefore, we are often left with the task of modeling the statistical process of the background along with our source.
#
# In typical spectral modeling, we find a few common cases when background is involved. If we have total counts ($S_i$) in $i^{\rm th}$ on $N$ bins observed for an exposure of $t_{\rm s}$ and also a measurement of $B_i$ background counts from looking off source for $t_{\rm b}$ seconds, we can then suppose a model for the source rate ($m_i$) and background rate ($b_i$).
#
# **Poisson source with Poisson background**
#
# This is described by a likelihood of the following form:
#
# $$ L = \prod^N_{i=1} \frac{(t_{\rm s}(m_i+b_i))^{S_i} e^{-t_{\rm s}(m_i+b_i)}}{S_i!} \times \frac{(t_{\rm b} b_i)^{B_i} e^{-t_{\rm b}b_i}}{B_i!}  $$
#
# which is a Poisson likelihood for the total model ($m_i +b_i$) conditional on the Poisson distributed background observation. This is the typical case for e.g. aperture x-ray instruments that observe a source region and then a background region. Both observations are Poisson distributed.
#
# **Poisson source with Gaussian background**
#
# This likelihood is similar, but the conditonal background distribution is described by Gaussian:
#
# $$ L = \prod^N_{i=1} \frac{(t_{\rm s}(m_i+b_i))^{S_i} e^{-t_{\rm s}(m_i+b_i)}}{S_i!} \times \frac{1}{\sigma_{b,i}\sqrt{2 \pi}} \exp \left[ \frac{({B_i} - t_{\rm b} b_i)^2} {2 \sigma_{b,i}^2} \right] $$
#
# where the $\sigma_{b,i}$ are the measured errors on $B_i$. This situation occurs e.g. when the background counts are estimated from a fitted model such as time-domain instruments that estimate the background counts from temporal fits to the lightcurve.
#
# In 3ML, we can fit a background model along with the the source model which allows for arbitrarily low background counts (in fact zero) in channels. The alternative is to use profile likelihoods where we first differentiate the likelihood with respect to the background model
#
# $$ \frac{ \partial L}{{\partial b_i}} = 0$$
#
# and solve for the $b_i$ that maximize the likelihood. Both the Poisson and Gaussian background profile likelihoods are described in the [XSPEC statistics guide](https://heasarc.gsfc.nasa.gov/xanadu/xspec/manual/XSappendixStatistics.html). This implicitly yields $N$ parameters to the model thus requiring at least one background count per channel. These profile likelihoods are the default Poisson likelihoods in 3ML when a background model is not used with a **SpectrumLike** (and its children, **DispersionSpectrumLike** and **OGIPLike**) plugin.
#
# Let's examine how to handle both cases.

# %%
import warnings

warnings.simplefilter("ignore")
import numpy as np

np.seterr(all="ignore")
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
# %%capture
from threeML import *

# %%
from jupyterthemes import jtplot

# %matplotlib inline
jtplot.style(context="talk", fscale=1, ticks=True, grid=False)
set_threeML_style()
silence_warnings()
import astropy.units as u

# %% [markdown]
# First we will create an observation where we have a simulated broken power law source spectrum along with an observed background spectrum. The background is a powerl law continuum with a Gaussian line.

# %%
# create the simulated observation

energies = np.logspace(1, 4, 151)

low_edge = energies[:-1]
high_edge = energies[1:]

# get a BPL source function
source_function = Broken_powerlaw(K=2, xb=300, piv=300, alpha=0.0, beta=-3.0)

# power law background function
background_function = Powerlaw(K=0.5, index=-1.5, piv=100.0) + Gaussian(
    F=50, mu=511, sigma=20
)

spectrum_generator = SpectrumLike.from_function(
    "fake",
    source_function=source_function,
    background_function=background_function,
    energy_min=low_edge,
    energy_max=high_edge,
)


spectrum_generator.view_count_spectrum()
# Out:
# 11:32:59 INFO      Auto-probed noise models:                                                    ]8;id=628507;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=306904;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#469\469]8;;\
#          INFO      - observation: poisson                                                       ]8;id=599906;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=436116;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#470\470]8;;\
#          INFO      - background: None                                                           ]8;id=958609;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=446884;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#471\471]8;;\
# 11:33:01 INFO      Auto-probed noise models:                                                    ]8;id=759103;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=779749;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#469\469]8;;\
#          INFO      - observation: poisson                                                       ]8;id=638616;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=912370;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#470\470]8;;\
#          INFO      - background: None                                                           ]8;id=448499;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=976791;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#471\471]8;;\
#          INFO      Auto-probed noise models:                                                    ]8;id=25280;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=466453;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#469\469]8;;\
#          INFO      - observation: poisson                                                       ]8;id=342992;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=56822;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#470\470]8;;\
#          INFO      - background: poisson                                                        ]8;id=203147;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=355393;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#471\471]8;;\
# 11:33:02 INFO      Auto-probed noise models:                                                    ]8;id=433221;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=501525;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#469\469]8;;\
#          INFO      - observation: poisson                                                       ]8;id=259847;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=255642;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#470\470]8;;\
#          INFO      - background: poisson                                                        ]8;id=132805;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=324248;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#471\471]8;;\

# %% [markdown]
# ## Using a profile likelihood
#
# We have very few counts counts in some channels (in fact sometimes zero), but let's assume we do not know the model for the background. In this case, we will use the profile Poisson likelihood.

# %%
# instance our source spectrum
bpl = Broken_powerlaw(piv=300, xb=500)

# instance a point source
ra, dec = 0, 0
ps_src = PointSource("source", ra, dec, spectral_shape=bpl)

# instance the likelihood model
src_model = Model(ps_src)

# pass everything to a joint likelihood object
jl_profile = JointLikelihood(src_model, DataList(spectrum_generator))


# fit the model
_ = jl_profile.fit()

# plot the fit in count space
_ = spectrum_generator.display_model(step=False)
# Out:
# 11:33:03 INFO      set the minimizer to minuit                                             ]8;id=879919;file:///home/runner/work/threeML/threeML/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=334715;file:///home/runner/work/threeML/threeML/threeML/classicMLE/joint_likelihood.py#1042\1042]8;;\
# Best fit values:
#                                                                result  \
# parameter
# source.spectrum.main.Broken_powerlaw.K               1.76 -0.13 +0.14
# source.spectrum.main.Broken_powerlaw.xb     (2.92 -0.13 +0.14) x 10^2
# source.spectrum.main.Broken_powerlaw.alpha     (-1.4 +/- 0.7) x 10^-1
# source.spectrum.main.Broken_powerlaw.beta              -2.79 +/- 0.14
#
#                                                        unit
# parameter
# source.spectrum.main.Broken_powerlaw.K      1 / (cm2 keV s)
# source.spectrum.main.Broken_powerlaw.xb                 keV
# source.spectrum.main.Broken_powerlaw.alpha
# source.spectrum.main.Broken_powerlaw.beta
# Correlation matrix:
#  1.00 -0.62  0.78  0.01
# -0.62  1.00 -0.48 -0.58
#  0.78 -0.48  1.00  0.01
#  0.01 -0.58  0.01  1.00
# Values of -log(likelihood) at the minimum:
#        -log(likelihood)
# fake          420.13564
# total         420.13564
# Values of statistical measures:
#      statistical measures
# AIC            848.547142
# BIC            860.313822

# %% [markdown]
# Our fit recovers the simulated parameters. However, we should have binned the spectrum up such that there is at least one background count per spectral bin for the profile to be valid.

# %%
spectrum_generator.rebin_on_background(1)

spectrum_generator.view_count_spectrum()

_ = jl_profile.fit()

_ = spectrum_generator.display_model(step=False)
# Out:
# 11:33:08 INFO      Now using 83 bins                                                           ]8;id=826150;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=951244;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#1673\1673]8;;\
# Best fit values:
#                                                                result  \
# parameter
# source.spectrum.main.Broken_powerlaw.K               1.78 -0.13 +0.15
# source.spectrum.main.Broken_powerlaw.xb     (2.85 -0.13 +0.14) x 10^2
# source.spectrum.main.Broken_powerlaw.alpha     (-1.2 +/- 0.8) x 10^-1
# source.spectrum.main.Broken_powerlaw.beta              -2.68 +/- 0.13
#
#                                                        unit
# parameter
# source.spectrum.main.Broken_powerlaw.K      1 / (cm2 keV s)
# source.spectrum.main.Broken_powerlaw.xb                 keV
# source.spectrum.main.Broken_powerlaw.alpha
# source.spectrum.main.Broken_powerlaw.beta
# Correlation matrix:
#  1.00 -0.63  0.78  0.02
# -0.63  1.00 -0.48 -0.59
#  0.78 -0.48  1.00  0.01
#  0.02 -0.59  0.01  1.00
# Values of -log(likelihood) at the minimum:
#        -log(likelihood)
# fake         307.361857
# total        307.361857
# Values of statistical measures:
#      statistical measures
# AIC            622.999575
# BIC            634.766254

# %% [markdown]
# ## Modeling the background
#
# Now let's try to model the background assuming we know that the background is a power law with a Gaussian line. We can extract a background plugin from the data by passing the original plugin to a classmethod of spectrum like.

# %%
# extract the background from the spectrum plugin.
# This works for OGIPLike plugins as well, though we could easily also just read
# in a bakcground PHA
background_plugin = SpectrumLike.from_background("bkg", spectrum_generator)
# Out:
# 11:33:10 INFO      Auto-probed noise models:                                                    ]8;id=147706;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=334804;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#469\469]8;;\
#          INFO      - observation: poisson                                                       ]8;id=915123;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=764729;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#470\470]8;;\
#          INFO      - background: None                                                           ]8;id=442665;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=970841;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#471\471]8;;\

# %% [markdown]
# This constructs a new plugin with only the observed background so that we can first model it.

# %%
background_plugin.view_count_spectrum()

# %% [markdown]
# We now construct our background model and fit it to the data. Let's assume we know that the line occurs at 511 keV, but we are unsure of its strength an width. We do not need to bin the data up because we are using a simple Poisson likelihood which is valid even when we have zero counts [Cash (1979)](http://adsabs.harvard.edu/abs/1979ApJ...228..939C).

# %%
# instance the spectrum setting the line's location to 511
bkg_spectrum = Powerlaw(piv=100) + Gaussian(F=50, mu=511)

# setup model parameters
# fix the line's location
bkg_spectrum.mu_2.fix = True

# nice parameter bounds
bkg_spectrum.K_1.bounds = (1e-4, 10)
bkg_spectrum.F_2.bounds = (0.0, 1000)
bkg_spectrum.sigma_2.bounds = (2, 30)

ps_bkg = PointSource("bkg", 0, 0, spectral_shape=bkg_spectrum)

bkg_model = Model(ps_bkg)


jl_bkg = JointLikelihood(bkg_model, DataList(background_plugin))


_ = jl_bkg.fit()

_ = background_plugin.display_model(
    step=False, data_color="#1A68F0", model_color="#FF9700"
)
# Out:
# 11:33:11 INFO      set the minimizer to minuit                                             ]8;id=299902;file:///home/runner/work/threeML/threeML/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=578723;file:///home/runner/work/threeML/threeML/threeML/classicMLE/joint_likelihood.py#1042\1042]8;;\
# Best fit values:
#                                                          result  \
# parameter
# bkg.spectrum.main.composite.K_1      (3.10 -0.23 +0.24) x 10^-1
# bkg.spectrum.main.composite.index_1              -1.36 +/- 0.04
# bkg.spectrum.main.composite.F_2              (2.6 +/- 0.5) x 10
# bkg.spectrum.main.composite.sigma_2          (2.0 +/- 0.4) x 10
#
#                                                 unit
# parameter
# bkg.spectrum.main.composite.K_1      1 / (cm2 keV s)
# bkg.spectrum.main.composite.index_1
# bkg.spectrum.main.composite.F_2          1 / (cm2 s)
# bkg.spectrum.main.composite.sigma_2              keV
# Correlation matrix:
#  1.00  0.11 -0.06 -0.05
#  0.11  1.00 -0.05 -0.05
# -0.06 -0.05  1.00  0.11
# -0.05 -0.05  0.11  1.00
# Values of -log(likelihood) at the minimum:
#        -log(likelihood)
# bkg          209.140706
# total        209.140706
# Values of statistical measures:
#      statistical measures
# AIC            426.557274
# BIC            438.323953

# %% [markdown]
# We now have a model and estimate for the background which we can use when fitting with the source spectrum. We now create a new plugin with just the total observation and pass our background plugin as the background argument.

# %%
modeled_background_plugin = SpectrumLike(
    "full",
    # here we use the original observation
    observation=spectrum_generator.observed_spectrum,
    # we pass the background plugin as the background!
    background=background_plugin,
)
# Out:
# 11:33:13 INFO      Background modeled from plugin: bkg                                          ]8;id=512788;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=877751;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#459\459]8;;\
#          INFO      Auto-probed noise models:                                                    ]8;id=936201;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=399384;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#469\469]8;;\
#          INFO      - observation: poisson                                                       ]8;id=271086;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=495735;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#470\470]8;;\
#          INFO      - background: poisson                                                        ]8;id=127959;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py\SpectrumLike.py]8;;\:]8;id=92617;file:///home/runner/work/threeML/threeML/threeML/plugins/SpectrumLike.py#471\471]8;;\

# %% [markdown]
# When we look at out count spectrum now, we will see the *predicted* background, rather than the measured one:

# %%
modeled_background_plugin.view_count_spectrum()

# %% [markdown]
# Now we simply fit the spectrum as we did in the profiled case. The background plugin's parameters are stored in our new plugin as nuissance parameters:

# %%
modeled_background_plugin.nuisance_parameters
# Out:
# OrderedDict([('cons_full',
#               Parameter cons_full = 1.0 []
#               (min_value = 0.8, max_value = 1.2, delta = 0.05, free = False)),
#              ('bkg_bkg_position_ra_full',
#               Parameter ra = 0.0 [deg]
#               (min_value = 0.0, max_value = 360.0, delta = 0.1, free = False)),
#              ('bkg_bkg_position_dec_full',
#               Parameter dec = 0.0 [deg]
#               (min_value = -90.0, max_value = 90.0, delta = 0.1, free = False)),
#              ('bkg_bkg_spectrum_main_composite_K_1_full',
#               Parameter K_1 = 0.309981504321747 [1 / (cm2 keV s)]
#               (min_value = 0.0001, max_value = 10.0, delta = 0.1, free = True)),
#              ('bkg_bkg_spectrum_main_composite_piv_1_full',
#               Parameter piv_1 = 100.0 [keV]
#               (min_value = None, max_value = None, delta = 0.1, free = False)),
#              ('bkg_bkg_spectrum_main_composite_index_1_full',
#               Parameter index_1 = -1.363355468201937 []
#               (min_value = -10.0, max_value = 10.0, delta = 0.20099999999999998, free = True)),
#              ('bkg_bkg_spectrum_main_composite_F_2_full',
#               Parameter F_2 = 26.055581437490908 [1 / (cm2 s)]
#               (min_value = 0.0, max_value = 1000.0, delta = 0.1, free = True)),
#              ('bkg_bkg_spectrum_main_composite_mu_2_full',
#               Parameter mu_2 = 511.0 [keV]
#               (min_value = None, max_value = None, delta = 0.1, free = False)),
#              ('bkg_bkg_spectrum_main_composite_sigma_2_full',
#               Parameter sigma_2 = 19.94398847613727 [keV]
#               (min_value = 2.0, max_value = 30.0, delta = 0.1, free = True)),
#              ('bkg_cons_bkg_full',
#               Parameter cons_bkg = 1.0 []
#               (min_value = 0.8, max_value = 1.2, delta = 0.05, free = False))])

# %% [markdown]
# and the fitting engine will use them in the fit. The parameters will still be connected to the background plugin and its model and thus we can free/fix them there as well as set priors on them.

# %%
# instance the source model... the background plugin has it's model already specified
bpl = Broken_powerlaw(piv=300, xb=500)

bpl.K.bounds = (1e-5, 1e1)
bpl.xb.bounds = (1e1, 1e4)

ps_src = PointSource("source", 0, 0, bpl)

src_model = Model(ps_src)


jl_src = JointLikelihood(src_model, DataList(modeled_background_plugin))

_ = jl_src.fit()
# Out:
# 11:33:14 INFO      set the minimizer to minuit                                             ]8;id=833424;file:///home/runner/work/threeML/threeML/threeML/classicMLE/joint_likelihood.py\joint_likelihood.py]8;;\:]8;id=585803;file:///home/runner/work/threeML/threeML/threeML/classicMLE/joint_likelihood.py#1042\1042]8;;\
# Best fit values:
#                                                                result  \
# parameter
# source.spectrum.main.Broken_powerlaw.K               1.66 -0.12 +0.13
# source.spectrum.main.Broken_powerlaw.xb     (2.92 -0.14 +0.15) x 10^2
# source.spectrum.main.Broken_powerlaw.alpha     (-2.1 +/- 0.7) x 10^-1
# source.spectrum.main.Broken_powerlaw.beta              -2.69 +/- 0.15
# K_1                                           (3.19 +/- 0.32) x 10^-1
# index_1                                                -1.34 +/- 0.04
# F_2                                                (2.2 +/- 0.4) x 10
# sigma_2                                            (2.1 +/- 0.4) x 10
#
#                                                        unit
# parameter
# source.spectrum.main.Broken_powerlaw.K      1 / (cm2 keV s)
# source.spectrum.main.Broken_powerlaw.xb                 keV
# source.spectrum.main.Broken_powerlaw.alpha
# source.spectrum.main.Broken_powerlaw.beta
# K_1                                         1 / (cm2 keV s)
# index_1
# F_2                                             1 / (cm2 s)
# sigma_2                                                 keV
# Correlation matrix:
#  1.00 -0.63  0.77  0.06  0.07 -0.18  0.00  0.00
# -0.63  1.00 -0.48 -0.61  0.02  0.24 -0.07 -0.04
#  0.77 -0.48  1.00  0.05  0.30 -0.27 -0.00 -0.00
#  0.06 -0.61  0.05  1.00 -0.22 -0.38  0.01  0.01
#  0.07  0.02  0.30 -0.22  1.00  0.10 -0.05 -0.04
# -0.18  0.24 -0.27 -0.38  0.10  1.00 -0.04 -0.03
#  0.00 -0.07 -0.00  0.01 -0.05 -0.04  1.00  0.22
#  0.00 -0.04 -0.00  0.01 -0.04 -0.03  0.22  1.00
# Values of -log(likelihood) at the minimum:
#        -log(likelihood)
# full         542.603911
# total        542.603911
# Values of statistical measures:
#      statistical measures
# AIC           1102.229098
# BIC           1125.292903

# %%
# over plot the joint background and source fits
fig = modeled_background_plugin.display_model(step=False)

_ = background_plugin.display_model(
    data_color="#1A68F0", model_color="#FF9700", model_subplot=fig.axes, step=False
)
